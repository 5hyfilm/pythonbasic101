# %%
with open('littleredridinghood.txt') as f:
    s = f.read()

# %%
s.split()
# Out:
# ['Once',
#  'upon',
#  'a',
#  'time',
#  'there',
#  'lived',
#  'in',
#  'a',
#  'certain',
#  'village',
#  'a',
#  'little',
#  'country',
#  'girl,',
#  'the',
#  'prettiest',
#  'creature',
#  'who',
#  'was',
#  'ever',
#  'seen.',
#  'Her',
#  'mother',
#  'was',
#  'excessively',
#  'fond',
#  'of',
#  'her;',
#  'and',
#  'her',
#  'grandmother',
#  'doted',
#  'on',
#  'her',
#  'still',
#  'more.',
#  'This',
#  'good',
#  'woman',
#  'had',
#  'a',
#  'little',
#  'red',
#  'riding',
#  'hood',
#  'made',
#  'for',
#  'her.',
#  'It',
#  'suited',
#  'the',
#  'girl',
#  'so',
#  'extremely',
#  'well',
#  'that',
#  'everybody',
#  'called',
#  'her',
#  'Little',
#  'Red',
#  'Riding',
#  'Hood.',
#  'One',
#  'day',
#  'her',
#  'mother,',
#  'having',
#  'made',
#  'some',
#  'cakes,',
#  'said',
#  'to',
#  'her,',
#  '"Go,',
#  'my',
#  'dear,',
#  'and',
#  'see',
#  'how',
#  'your',
#  'grandmother',
#  'is',
#  'doing,',
#  'for',
#  'I',
#  'hear',
#  'she',
# ...

# %%
import operator
d = {}
for i in s.split():
    d[i] = d.get(i,0)+1
sorted_d = sorted(d.items(), key=operator.itemgetter(1))

# %%
d
# Out:
# {'Once': 1,
#  'upon': 4,
#  'a': 17,
#  'time': 2,
#  'there': 2,
#  'lived': 2,
#  'in': 7,
#  'certain': 1,
#  'village': 1,
#  'little': 9,
#  'country': 1,
#  'girl,': 1,
#  'the': 37,
#  'prettiest': 1,
#  'creature': 1,
#  'who': 8,
#  'was': 11,
#  'ever': 1,
#  'seen.': 1,
#  'Her': 1,
#  'mother': 2,
#  'excessively': 1,
#  'fond': 1,
#  'of': 9,
#  'her;': 1,
#  'and': 27,
#  'her': 18,
#  'grandmother': 5,
#  'doted': 1,
#  'on': 1,
#  'still': 1,
#  'more.': 1,
#  'This': 1,
#  'good': 3,
#  'woman': 2,
#  'had': 4,
#  'red': 1,
#  'riding': 1,
#  'hood': 1,
#  'made': 2,
#  'for': 3,
#  'her.': 1,
#  'It': 2,
#  'suited': 1,
#  'girl': 2,
#  'so': 1,
#  'extremely': 1,
#  'well': 1,
#  'that': 3,
#  'everybody': 1,
#  'called': 1,
#  'Little': 10,
#  'Red': 10,
#  'Riding': 10,
#  'Hood.': 1,
#  'One': 1,
#  'day': 1,
#  'mother,': 1,
#  'having': 1,
#  'some': 3,
#  'cakes,': 1,
#  'said': 6,
#  'to': 17,
#  'her,': 4,
#  '"Go,': 1,
#  'my': 7,
#  'dear,': 1,
# ...

# %%
x = [0,1,2,3,4,5]
print(x[:])
# Out:
# [0, 1, 2, 3, 4, 5]
